# %%
import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split 
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import metrics

# %% [markdown]
# Bag of words prototype on a small sample of the data

# %%
def folder_list_pd(paths,file_list,num=5000): #take num files
    '''
    Return dataframe with texts
    Pass num=None to use all files.
    '''
    appeals = []
    files = []
    count = 0
    for infile in file_list[0:num]:
        count += 1
        if count % 1000 == 0:
            print('done with ' + str(count))
        read_ok = False
        for path in paths:
            file = os.path.join(path,infile)
            try:
                with open(file) as f:
                    lines = f.read().strip().replace('\n',' ').replace('\t', ' ')
                    appeals.append(lines)
                    files.append(str(infile))
                    read_ok = True
                    break
            except:
                continue
        if not read_ok:
            print("WARNING: Could not find " + infile + " in any of the given paths")

    appeals_df = pd.DataFrame(columns = ['Text','File'])
    appeals_df.Text = appeals
    appeals_df.File = files
    
    return appeals_df

# %%
def match_target(data):
    '''
    Add target variable
    '''
    keys = pd.read_csv('file_target.csv')
    merged = data.merge(keys, on='File', how='left')
    merged.drop(['File','Unnamed: 0'], axis =1,inplace=True)
    
    return merged

# %%
if __name__ == '__main__':
    path = 'text_appeals'
    file_id = list(pd.read_csv('file_target.csv').File)
    appeals = folder_list_pd(path,file_id)
    merged = match_target(appeals)
    X = pd.DataFrame(merged['Text'])
    Y = pd.DataFrame(merged['Y'])

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)
# Out:
# done with 1000
# done with 2000
# done with 3000
# done with 4000
# done with 5000

# %%
#Read map from file to outcome
file_id = list(pd.read_csv('file_target.csv').File)
print(len(file_id))
# Out:
# 35232

# %%
#Read appeals into a dataframe
paths = ['text_appeals', 
          'NY-Appellate-Scraping/raw data/courtdoc-2017/txt',
         'NY-Appellate-Scraping/raw data/courtdoc-2015-2016/txt']
         
appeals = folder_list_pd(paths,file_id, None)
appeals.to_csv('consolidated_appeals.csv')
print(len(appeals))
# Out:
# done with 1000
# done with 2000
# done with 3000
# done with 4000
# done with 5000
# done with 6000
# done with 7000
# done with 8000
# done with 9000
# done with 10000
# done with 11000
# done with 12000
# done with 13000
# done with 14000
# done with 15000
# done with 16000
# done with 17000
# done with 18000
# done with 19000
# done with 20000
# done with 21000
# done with 22000
# done with 23000
# done with 24000
# done with 25000
# done with 26000
# done with 27000
# done with 28000
# done with 29000
# done with 30000
# done with 31000
# done with 32000
# done with 33000
# done with 34000
# done with 35000
# 35232

# %%
#Match appeals to outcomes
merged = match_target(appeals)
merged.head()
# Out:
#                                                 Text  Y
# 0  People v Branch  2003 NY Slip Op 18059 [1 AD3d...  1
# 1  People v Brunson  2003 NY Slip Op 18060 [1 AD3...  0
# 2  People v Cabrera  2003 NY Slip Op 18061 [1 AD3...  0
# 3  People v Deeds  2003 NY Slip Op 18062 [1 AD3d ...  0
# 4  People v Felix  2003 NY Slip Op 18063 [1 AD3d ...  0

# %%
#Split into test and train
X = pd.DataFrame(merged['Text'])
Y = pd.DataFrame(merged['Y'])

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)

# %%
merged.to_csv('merged.csv')

# %% [markdown]
# ### Read data from file

# %%
merged = pd.read_csv('merged.csv')

X = pd.DataFrame(merged['Text'])
Y = pd.DataFrame(merged['Y'])

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)

# %% [markdown]
# ### Models including all words
# This will create leakage as outcome is included in the training set. However, it is still useful for the first iteration to ensure the model works as expected

# %%
#Create vectorizers
count_vect = CountVectorizer(min_df=1, stop_words='english', binary='True')

#Convert a collection of text documents to a matrix of token counts
X_vect = count_vect.fit(X_train['Text'])

#Transform the training and test data to sparse format
vect_train = X_vect.transform(X_train['Text'])
vect_test = X_vect.transform(X_test['Text'])

# %%
#See the vocabulary
X_vect.vocabulary_
# Out:
# {u'darryle': 24534,
#  u'elvy': 27914,
#  u'87388': 14149,
#  u'glisson': 31763,
#  u'darryll': 24535,
#  u'sowell': 54354,
#  u'sonja': 54238,
#  u'wahedi': 60024,
#  u'woods': 60994,
#  u'tetenbaum': 56798,
#  u'hanging': 32877,
#  u'woody': 61004,
#  u'suzana': 55943,
#  u'tingly': 57136,
#  u'27\xbd': 12300,
#  u'localized': 39546,
#  u'banasiak': 17577,
#  u'disobeying': 26315,
#  u'hennings': 33419,
#  u'19398': 11548,
#  u'sprague': 54618,
#  u'19395': 11546,
#  u'5987': 13487,
#  u'scalerico': 51985,
#  u'trifold': 57779,
#  u'opener': 44858,
#  u'crossbar': 23968,
#  u'rickman': 50588,
#  u'honeycutt': 33878,
#  u'betancurth': 18445,
#  u'tutiven': 58042,
#  u'kleiman': 37595,
#  u'stipulate': 55113,
#  u'mpairment': 42901,
#  u'appropriation': 16367,
#  u'trileptal': 57784,
#  u'taj': 56222,
#  u'zaruma': 61505,
#  u'screaming': 52355,
#  u'weiskopff': 60415,
#  u'wooded': 60979,
#  u'grueling': 32375,
#  u'wooden': 60980,
#  u'ewool': 28777,
#  u'wednesday': 60350,
#  u'lisojo': 39401,
#  u'tak': 56223,
#  u'crotch': 23983,
#  u'schunk': 52242,
#  u'suppressible': 55809,
#  u'sooty': 54256,
#  u'0052': 495,
#  u'0051': 484,
#  u'0050': 475,
#  u'scrapes': 52341,
#  u'accusatorial': 14733,
#  u'270': 12262,
#  u'271': 12269,
#  u'272': 12277,
#  u'273': 12281,
#  u'274': 12284,
#  u'275': 12285,
#  u'276': 12287,
#  u'277': 12289,
#  u'278': 12293,
#  u'279': 12296,
#  u'scraped': 52340,
#  u'inanimate': 34779,
#  u'errors': 28473,
#  u'haenel': 32667,
#  u'joele': 36514,
#  u'cooking': 23335,
#  u'demerus': 25233,
#  u'databank': 24568,
#  u'succumb': 55593,
#  u'submerged': 55497,
#  u'mccutchen': 41222,
#  u'presentence': 47642,
#  u'crouch': 23986,
#  u'tessitore': 56776,
#  u'9256': 14240,
#  u'mailings': 40222,
#  u'denominations': 25319,
#  u'perforations': 46254,
#  u'saylor': 51964,
#  u'10704': 10005,
#  u'soulia': 54313,
#  u'ad3d': 14852,
#  u'china': 21644,
#  u'luczka': 39880,
#  u'affiliated': 15125,
#  u'chinn': 21650,
#  u'shavuo': 53112,
#  u'finkel': 29909,
#  u'mestres': 41808,
#  u'quart': 48481,
#  u'kids': 37409,
#  u'kidy': 37411,
#  u'climbed': 22103,
#  u'spotto': 54610,
#  u'controversy': 23268,
#  u'muirhead': 42959,
#  u'kidd': 37396,
#  u'07463': 7192,
#  u'neurologist': 43617,
#  u'spotty': 54611,
#  u'jairam': 36073,
#  u'appropriately': 16365,
#  u'07461': 7190,
#  u'projection': 47964,
#  u'armstead': 16584,
#  u'nellys': 43551,
#  u'etheart': 28630,
#  u'giruzzi': 31676,
#  u'mclaurin': 41370,
#  u'sterk': 55036,
#  u'stern': 55038,
#  u'09194': 8802,
#  u'battista': 17925,
#  u'battiste': 17926,
#  u'bubbles': 19846,
#  u'dna': 26587,
#  u'century': 21200,
#  u'sidebars': 53502,
#  u'beriguette': 18345,
#  u'music': 43109,
#  u'distortions': 26479,
#  u'mcclusky': 41169,
#  u'06594': 6359,
#  u'populations': 47167,
#  u'dekenipp': 25027,
#  u'adgate': 14933,
#  u'boorman': 19120,
#  u'serially': 52759,
#  u'03132': 3030,
#  u'exch': 28832,
#  u'circumstances': 21869,
#  u'reingold': 49707,
#  u'intake': 35406,
#  u'morally': 42678,
#  u'locked': 39559,
#  u'isidore': 35849,
#  u'jihhad': 36461,
#  u'seepersaud': 52555,
#  u'abducting': 14460,
#  u'meadows': 41464,
#  u'locker': 39560,
#  u'locket': 39564,
#  u'busyness': 20142,
#  u'gershon': 31477,
#  u'wiretapping': 60842,
#  u'sinking': 53690,
#  u'scarincio': 52029,
#  u'wang': 60137,
#  u'hyatt': 34268,
#  u'unjust': 58660,
#  u'wani': 60139,
#  u'00850': 816,
#  u'disparagement': 26325,
#  u'titanium': 57197,
#  u'miele': 41964,
#  u'pinta': 46754,
#  u'want': 60142,
#  u'961': 14302,
#  u'rayon': 49101,
#  u'pinto': 46755,
#  u'absolute': 14590,
#  u'moshman': 42787,
#  u'20258': 11872,
#  u'20259': 11873,
#  u'clammers': 21953,
#  u'brandon': 19429,
#  u'kingsberry': 37491,
#  u'shameek': 52982,
#  u'beyer': 18478,
#  u'travel': 57660,
#  u'20251': 11866,
#  u'20256': 11870,
#  u'20257': 11871,
#  u'20254': 11868,
#  u'20255': 11869,
#  u'hough': 34028,
#  u'travet': 57670,
#  u'playback': 46899,
#  u'dangerfield': 24430,
#  u'barstools': 17793,
#  u'quimbley': 48552,
#  u'1177': 10183,
#  u'1176': 10182,
#  u'1175': 10180,
#  u'1174': 10178,
#  u'1173': 10177,
#  u'1172': 10175,
#  u'1171': 10173,
#  u'1170': 10172,
#  u'07677': 7396,
#  u'sanabria': 51711,
#  u'07675': 7394,
#  u'07674': 7393,
#  u'highsmith': 33593,
#  u'07672': 7391,
#  u'1179': 10185,
#  u'1178': 10184,
#  u'festus': 29723,
#  u'wrong': 61124,
#  u'seda': 52522,
#  u'sentencing': 52706,
#  u'gautreaux': 31276,
#  u'desirie': 25573,
#  u'dunster': 27189,
#  u'1494': 10674,
#  u'eyers': 29136,
#  u'caisson': 20284,
#  u'amaya': 15785,
#  u'sickening': 53489,
#  u'tulip': 57953,
#  u'mccoski': 41184,
#  u'capeci': 20550,
#  u'perpetrator': 46342,
#  u'rotblatt': 51131,
#  u'nonsensical': 44064,
#  u'davlon': 24613,
#  u'goldfeld': 31857,
#  u'welcomed': 60428,
#  u'hebert': 33267,
#  u'concurrence': 22823,
#  u'620': 13546,
#  u'kuey': 37984,
#  u'627': 13559,
#  u'rewarded': 50484,
#  u'activating': 14824,
#  u'zak': 61465,
#  u'walek': 60076,
#  u'mckeney': 41340,
#  u'fit': 29989,
#  u'bringing': 19623,
#  u'wolland': 60946,
#  u'occupations': 44519,
#  u'uriah': 59001,
#  u'fid': 29771,
#  u'latney': 38533,
#  u'2656f': 12242,
#  u'reentered': 49523,
#  u'probst': 47852,
#  u'cullop': 24110,
#  u'fin': 29863,
#  u'fil': 29823,
#  u'zucker': 61670,
#  u'maneiro': 40410,
#  u'vouchers': 59955,
#  u'memorialize': 41662,
#  u'yehidie': 61302,
#  u'effects': 27580,
#  u'06108': 5897,
#  u'06109': 5898,
#  u'06106': 5895,
#  u'06107': 5896,
#  u'06104': 5893,
#  u'sixteen': 53746,
#  u'grinage': 32289,
#  u'06103': 5892,
#  u'06100': 5889,
#  u'06101': 5890,
#  u'remelt': 49874,
#  u'quattlebaum': 48494,
#  u'bazemore': 17973,
#  u'barton': 17816,
#  u'lucero': 39856,
#  u'arron': 16656,
#  u'bartow': 17817,
#  u'arrow': 16657,
#  u'ingrid': 35161,
#  u'klinger': 37613,
#  u'valladi': 59201,
#  u'burial': 20043,
#  u'trickery': 57766,
#  u'turpeau': 58021,
#  u'allah': 15561,
#  u'allan': 15563,
#  u'393': 12727,
#  u'392': 12726,
#  u'391': 12723,
#  u'390': 12721,
#  u'397': 12744,
#  u'396': 12734,
#  u'395': 12733,
#  u'394': 12732,
#  u'399': 12749,
#  u'398': 12745,
#  u'tricked': 57765,
#  u'getch': 31498,
#  u'batchelor': 17892,
#  u'lipson': 39379,
#  u'gradation': 32037,
#  u'mason': 40834,
#  u'mazur': 41077,
#  u'stasiak': 54877,
#  u'encourage': 28085,
#  u'goley': 31874,
#  u'goldwire': 31873,
#  u'gilmour': 31621,
#  u'thacher': 56826,
#  u'misrepresentations': 42306,
#  u'bonelly': 19059,
#  u'abbott': 14440,
#  u'koonce': 37775,
#  u'sheetrock': 53154,
#  u'bonelli': 19058,
#  u'doorga': 26779,
#  u'ruis': 51297,
#  u'corrects': 23512,
#  u'estimate': 28603,
#  u'universally': 58656,
#  u'silent': 53586,
#  u'calimeri': 20340,
#  u'ogborn': 44620,
#  u'chiaro': 21597,
#  u'saladeen': 51576,
#  u'immunities': 34572,
#  u'chiara': 21592,
#  u'receipted': 49270,
#  u'ministries': 42127,
#  u'disturbed': 26505,
#  u'caminero': 20420,
#  u'dentures': 25341,
#  u'giallombardo': 31533,
#  u'ineffectively': 35026,
#  u'mendacity': 41682,
#  u'mccafferty': 41113,
#  u'chronic': 21747,
#  u'farquhar': 29409,
#  u'52105': 13262,
#  u'stoneham': 55164,
#  u'disfigured': 26250,
#  u'105632': 9947,
#  u'reciprocally': 49304,
#  u'maladies': 40286,
#  u'fecu': 29541,
#  u'laviolette': 38604,
#  u'00362': 346,
#  u'seizures': 52601,
#  u'bilzerian': 18602,
#  u'olds': 44689,
#  u'renovated': 49974,
#  u'service': 52793,
#  u'forrester': 30473,
#  u'masten': 40869,
#  u'00364': 348,
#  u'goldberger': 31848,
#  u'reuben': 50402,
#  u'needed': 43481,
#  u'master': 40870,
#  u'seeber': 52543,
#  u'tumey': 57965,
#  u'inocencio': 35246,
#  u'cookhorne': 23333,
#  u'genesis': 31387,
#  u'caitlyn': 20286,
#  u'04618': 4457,
#  u'04619': 4458,
#  u'rewards': 50486,
#  u'09228': 8831,
#  u'09229': 8832,
#  u'09226': 8829,
#  u'04611': 4451,
#  u'04612': 4452,
#  u'04613': 4453,
#  u'09222': 8825,
#  u'09223': 8826,
#  u'04616': 4456,
#  u'09221': 8824,
#  u'00508': 482,
#  u'00509': 483,
#  u'task': 56423,
#  u'mutilated': 43133,
#  u'versage': 59556,
#  u'00501': 477,
#  u'nonconstitutional': 43937,
#  u'00503': 478,
#  u'nicometo': 43757,
#  u'00505': 479,
#  u'positively': 47239,
#  u'00507': 481,
#  u'feasibility': 29525,
#  u'ahmed': 15278,
#  u'saeed': 51509,
#  u'duckworth': 27108,
#  u'handcuffs': 32830,
#  u'fyall': 30959,
#  u'idly': 34415,
#  u'idle': 34412,
#  u'exclaimed': 28843,
#  u'friend': 30739,
#  u'feeling': 29562,
#  u'gorman': 31958,
#  u'kuletsky': 37999,
#  u'bogar': 18973,
#  u'steller': 54980,
#  u'6813': 13701,
#  u'sustaining': 55923,
#  u'6814': 13702,
#  u'consenting': 23019,
#  u'bogan': 18972,
#  u'dozed': 26922,
#  u'mishra': 42256,
#  u'skadden': 53759,
#  u'arousal': 16609,
#  u'urinate': 59008,
#  u'vidro': 59658,
#  u'dozen': 26923,
#  u'foundational': 30531,
#  u'affairs': 15110,
#  u'hymen': 34290,
#  u'craver': 23801,
#  u'paramedics': 45650,
#  u'salvadon': 51654,
#  u'101': 9606,
#  u'mickle': 41920,
#  u'hymes': 34292,
#  u'concedes': 22770,
#  u'45th': 12951,
#  u'demetrius': 25239,
#  u'committing': 22576,
#  u'jammed': 36127,
#  u'nabarrete': 43184,
#  u'thyroff': 57037,
#  u'diminishing': 26007,
#  u'eliminates': 27814,
#  u'graebe': 32052,
#  u'03349': 3242,
#  u'03348': 3241,
#  u'mouth': 42862,
#  u'steinhardt': 54973,
#  u'conceded': 22768,
#  u'03343': 3236,
#  u'03342': 3235,
#  u'03341': 3234,
#  u'rotestations': 51134,
#  u'03347': 3240,
#  u'03346': 3239,
#  u'03345': 3238,
#  u'depaula': 25379,
#  u'bradford': 19372,
#  u'singer': 53672,
#  u'alligood': 15605,
#  u'yanked': 61253,
#  u'roddy': 50871,
#  u'__us': 14381,
#  u'107': 10003,
#  u'tech': 56531,
#  u'fugitives': 30833,
#  u'costello': 23588,
#  u'scream': 52353,
#  u'02658': 2579,
#  u'saying': 51959,
#  u'adanjeandel': 14870,
#  u'franklyn': 30611,
#  u'dickey': 25865,
#  u'lookback': 39664,
#  u'teresa': 56701,
#  u'perjurous': 46294,
#  u'assuaged': 16907,
#  u'dauch': 24580,
#  u'ufares': 58187,
#  u'tempted': 56640,
#  u'prefatory': 47538,
#  u'shampine': 52994,
#  u'07992': 7695,
#  u'orleans': 45015,
#  u'07990': 7693,
#  u'07991': 7694,
#  u'07996': 7699,
#  u'07997': 7700,
#  u'07994': 7697,
#  u'07995': 7698,
#  u'07998': 7701,
#  u'07999': 7702,
#  u'rico': 50591,
#  u'assaultive': 16844,
#  u'bliss': 18827,
#  u'rick': 50577,
#  u'rich': 50559,
#  u'rice': 50558,
#  u'rica': 50546,
#  u'twanek': 58055,
#  u'plate': 46880,
#  u'puchi': 48232,
#  u'plato': 46887,
#  u'platt': 46889,
#  u'03103': 3002,
#  u'mcnab': 41400,
#  u'savoca': 51935,
#  u'caribe': 20689,
#  u'altogether': 15726,
#  u'feld': 29590,
#  u'staphylococcal': 54833,
#  u'massmann': 40862,
#  u'oeser': 44581,
#  u'jaguar': 36039,
#  u'rectal': 49419,
#  u'accordance': 14698,
#  u'patch': 45866,
#  u'eyelids': 29134,
#  u'totman': 57420,
#  u'boarded': 18920,
#  u'aadam': 14406,
#  u'03665': 3547,
#  u'precluding': 47470,
#  u'programmatic': 47938,
#  u'yosttin': 61375,
#  u'clarified': 21971,
#  u'sensitivity': 52697,
#  u'07336': 7067,
#  u'02121': 2068,
#  u'02122': 2069,
#  u'07335': 7066,
#  u'07332': 7063,
#  u'eschewing': 28517,
#  u'07330': 7061,
#  u'02127': 2074,
#  u'02128': 2075,
#  u'02129': 2076,
#  u'04550': 4391,
#  u'almog': 15659,
#  u'07338': 7069,
#  u'07339': 7070,
#  u'07515': 7243,
#  u'04979': 4805,
#  u'04978': 4804,
#  u'lots': 39739,
#  u'04974': 4800,
#  u'04977': 4803,
#  u'04976': 4802,
#  u'04971': 4797,
#  u'04970': 4796,
#  u'04973': 4799,
#  u'lott': 39740,
#  u'nonrecord': 44049,
#  u'dalhouse': 24361,
#  u'laning': 38347,
#  u'ira': 35740,
#  u'imprimatur': 34711,
#  u'wedra': 60352,
#  u'geenberg': 31329,
#  u'rayborn': 49081,
#  u'letting': 39058,
#  u'extend': 29064,
#  u'nature': 43379,
#  u'extent': 29074,
#  u'wheelbarrow': 60527,
#  u'tendons': 56660,
#  u'09897': 9417,
#  u'asfia': 16760,
#  u'boardman': 18922,
#  u'6779': 13689,
#  u'veer': 59390,
#  u'ryerson': 51405,
#  u'zellan': 61546,
#  u'6776': 13688,
#  u'heating': 33258,
#  u'varmette': 59335,
#  u'windham': 60776,
#  u'moravia': 42685,
#  u'eradicate': 28391,
#  u'rehash': 49659,
#  u'fentanyl': 29659,
#  u'foreclosing': 30373,
#  u'charney': 21431,
#  u'testimoniality': 56792,
#  u'unhealed': 58592,
#  u'fondled': 30294,
#  u'haggerty': 32684,
#  u'hahlbohm': 32691,
#  u'athan': 16949,
#  u'escalade': 28497,
#  u'dowsett': 26913,
#  u'blonde': 18843,
#  u'01473': 1436,
#  u'01472': 1435,
#  u'01471': 1434,
#  u'01470': 1433,
#  u'01477': 1440,
#  u'01476': 1439,
#  u'01475': 1438,
#  u'frd': 30650,
#  u'union': 58638,
#  u'01479': 1442,
#  u'01478': 1441,
#  u'kasten': 37029,
#  u'wyman': 61155,
#  u'destructible': 25612,
#  u'craig': 23777,
#  u'1678': 10916,
#  u'fry': 30802,
#  u'aleem': 15458,
#  u'tallest': 56263,
#  u'hepp': 33433,
#  u'deskovic': 25578,
#  u'mangual': 40430,
#  u'retrospect': 50386,
#  u'spit': 54551,
#  u'jarris': 36211,
#  u'arkim': 16553,
#  u'czapranski': 24303,
#  u'davy': 24618,
#  u'1674': 10912,
#  u'dave': 24596,
#  u'jarrin': 36210,
#  u'invalidated': 35645,
#  u'doubts': 26862,
#  u'aguayo': 15251,
#  u'rollock': 50949,
#  u'misconstrues': 42230,
#  u'easter': 27400,
#  u'excellus': 28815,
#  u'contingencies': 23192,
#  u'professionally': 47911,
#  u'1671': 10909,
#  u'employ': 28031,
#  u'fr2': 30561,
#  u'misconstrued': 42229,
#  u'miniature': 42109,
#  u'withfield': 60877,
#  u'fr4': 30562,
#  u'leitzsey': 38874,
#  u'05200': 5020,
#  u'05201': 5021,
#  u'05202': 5022,
#  u'deferring': 24934,
#  u'05204': 5024,
#  u'05205': 5025,
#  u'05206': 5026,
#  u'05207': 5027,
#  u'05208': 5028,
#  u'fumelli': 30874,
#  u'mcaloney': 41095,
#  u'verges': 59519,
#  u'kohl': 37736,
#  u'kohm': 37738,
#  u'elmira': 27872,
#  u'mirabella': 42159,
#  u'eighteen': 27664,
#  u'anhedonia': 16049,
#  u'invalidates': 35646,
#  u'conditioner': 22840,
#  u'5050': 13113,
#  u'vainberg': 59157,
#  u'keyontay': 37329,
#  u'memorial': 41661,
#  u'recover': 49402,
#  u'ignored': 34448,
#  u'anybody': 16225,
#  u'remand': 49853,
#  u'dazzo': 24657,
#  u'honk': 33884,
#  u'split': 54569,
#  u'kalford': 36867,
#  u'principals': 47783,
#  u'duchnowski': 27102,
#  u'18893': 11396,
#  u'boiled': 18997,
#  u'inadvertently': 34777,
#  u'kushner': 38022,
#  u'vivien': 59848,
#  u'qualifications': 48434,
#  u'workforce': 61036,
#  u'kindell': 37478,
#  u'consents': 23020,
#  u'boiler': 18998,
#  u'rulebook': 51305,
#  u'weinstock': 60402,
#  u'kisbech': 37549,
#  u'downwardly': 26911,
#  u'furlough': 30917,
#  u'peremptory': 46240,
#  u'03129': 3027,
#  u'02465': 2403,
#  u'academic': 14631,
#  u'02467': 2405,
#  u'02466': 2404,
#  u'02461': 2399,
#  u'02460': 2398,
#  u'02463': 2401,
#  u'02462': 2400,
#  u'kamins': 36900,
#  u'corporate': 23488,
#  u'massaging': 40845,
#  u'browsing': 19770,
#  u'05734': 5535,
#  u'murtaugh': 43089,
#  u'18760': 11343,
#  u'cobado': 22227,
#  u'dtap': 27074,
#  u'04153': 4019,
#  u'04152': 4018,
#  u'04151': 4017,
#  u'04150': 4016,
#  u'04157': 4023,
#  u'04156': 4022,
#  u'04155': 4021,
#  u'04154': 4020,
#  u'airbag': 15317,
#  u'04159': 4025,
#  u'04158': 4024,
#  u'bellmore': 18199,
#  u'brandish': 19423,
#  u'lasso': 38481,
#  u'danhaile': 24436,
#  u'hai': 32693,
#  u'hal': 32732,
#  u'ham': 32778,
#  u'han': 32820,
#  u'hao': 32910,
#  u'bribing': 19572,
#  u'espouses': 28556,
#  u'hae': 32664,
#  u'hay': 33166,
#  u'mcnamara': 41403,
#  u'kalvin': 36889,
#  u'duffel': 27124,
#  u'quagliata': 48427,
#  u'espoused': 28555,
#  u'senecal': 52674,
#  u'fortin': 30494,
#  u'schiener': 52131,
#  u'naasir': 43182,
#  u'municipal': 43028,
#  u'osman': 45080,
#  u'survival': 55889,
#  u'chayanne': 21490,
#  u'unequivocally': 58536,
#  u'palazzo': 45505,
#  u'indicative': 34962,
#  u'clustered': 22194,
#  u'shadow': 52910,
#  u'replace': 50046,
#  u'masonic': 40835,
#  u'sonberg': 54230,
#  u'01025': 996,
#  u'gade': 30974,
#  u'alice': 15529,
#  u'goldfine': 31858,
#  u'lacroix': 38134,
#  u'knipel': 37662,
#  u'teribury': 56705,
#  u'dedaj': 24854,
#  u'misdemeanors': 42234,
#  u'attorney': 17041,
#  u'disks': 26284,
#  u'ubmit': 58164,
#  u'crowd': 23993,
#  u'crowe': 23998,
#  u'crown': 24002,
#  u'crowl': 24000,
#  u'tookes': 57326,
#  u'captive': 20593,
#  u'emphases': 28018,
#  u'pinkney': 46738,
#  u'mosquea': 42793,
#  u'fiduciary': 29784,
#  u'52nd': 13303,
#  u'screahben': 52352,
#  u'vshaw': 59970,
#  u'utsey': 59089,
#  u'latecomer': 38495,
#  u'pileggi': 46686,
#  u'lockdown': 39557,
#  u'inhuman': 35184,
#  u'gambale': 31080,
#  u'plucked': 46958,
#  u'ecstasy': 27477,
#  u'uceta': 58171,
#  u'jahteek': 36056,
#  u'gotshal': 31987,
#  u'rookey': 51022,
#  u'binder': 18605,
#  u'estwick': 28621,
#  u'stokes': 55150,
#  u'weinber': 60390,
#  u'13989': 10487,
#  u'ader': 14927,
#  u'anomalous': 16116,
#  u'jazeke': 36265,
#  u'mussenden': 43114,
#  u'kilgore': 37431,
#  u'pizzaro': 46823,
#  u'kilada': 37427,
#  u'larossa': 38435,
#  u'onikosi': 44808,
#  u'oniel': 44807,
#  u'equcon': 28369,
#  u'maxwell': 41029,
#  u'marshall': 40744,
#  u'honeymoon': 33880,
#  u'nongovernmental': 43987,
#  u'angona': 16040,
#  u'administer': 14980,
#  u'beings': 18137,
#  u'inapplicability': 34780,
#  u'marshals': 40745,
#  u'hallucinogenic': 32763,
#  u'shoots': 53336,
#  u'reciprocity': 49305,
#  u'fabric': 29169,
#  u'suffice': 55625,
#  u'raped': 48940,
#  u'absolutely': 14591,
#  u'grasping': 32126,
#  u'rapes': 48941,
#  u'5867': 13460,
#  u'contusions': 23276,
#  u'grooms': 32330,
#  u'dowsey': 26914,
#  u'shireen': 53282,
#  u'denoting': 25325,
#  u'eleby': 27734,
#  u'vindra': 59741,
#  u'safeguard': 51516,
#  u'dialed': 25819,
#  u'natanel': 43352,
#  u'delegation': 25074,
#  u'pretextual': 47702,
#  u'egaveria': 27618,
#  u'presurrender': 47692,
#  u'arrays': 16630,
#  u'matyus': 40984,
#  u'meally': 41471,
#  u'dante': 24461,
#  u'schompert': 52203,
#  u'complications': 22690,
#  u'crider': 23880,
#  u'smashed': 53970,
#  u'19587': 11608,
#  u'19585': 11607,
#  u'dues': 27121,
#  u'chatelain': 21463,
#  u'19581': 11605,
#  u'passenger': 45828,
#  u'disgrace': 26254,
#  u'hysterical': 34334,
#  u'bedsheet': 18084,
#  u'signification': 53560,
#  u'jazzmone': 36270,
#  u'tooth': 57339,
#  u'mckiver': 41358,
#  u'kylstra': 38056,
#  u'standardized': 54807,
#  u'altona': 15728,
#  u'slurring': 53947,
#  u'chafla': 21285,
#  u'eventual': 28720,
#  u'wacker': 60000,
#  u'dowling': 26893,
#  u'role': 50932,
#  u'brent': 19538,
#  u'rolf': 50935,
#  u'crowne': 24003,
#  u'5933': 13475,
#  u'vegetative': 59398,
#  u'ritts': 50732,
#  u'wordlessly': 61025,
#  u'roll': 50938,
#  u'colesvintong': 22377,
#  u'intend': 35426,
#  u'loret': 39709,
#  u'palms': 45529,
#  u'kitsos': 37573,
#  u'transported': 57636,
#  u'nonnon': 44015,
#  u'youmans': 61377,
#  u'devon': 25751,
#  u'intent': 35438,
#  u'7942': 13990,
#  u'smelling': 53978,
#  u'variable': 59318,
#  u'hawker': 33160,
#  u'hawkes': 33161,
#  u'explosions': 29031,
#  u'loren': 39703,
#  u'shootout': 53335,
#  u'23ad3d': 12114,
#  u'16911': 10936,
#  u'eckless': 27464,
#  u'overturned': 45341,
#  u'branton': 19444,
#  u'bostic': 19204,
#  u'childs': 21630,
#  u'chaim': 21287,
#  u'chain': 21288,
#  u'07904': 7611,
#  u'ost': 45095,
#  u'aleman': 15465,
#  u'raggs': 48705,
#  u'atiba': 16957,
#  u'mcghee': 41273,
#  u'chair': 21293,
#  u'ose': 45069,
#  u'amplification': 15892,
#  u'hutchins': 34250,
#  u'mitigation': 42371,
#  u'freelance': 30679,
#  u'soscia': 54295,
#  u'crates': 23797,
#  u'disotell': 26323,
#  u'aponte': 16259,
#  u'crated': 23796,
#  u'reimels': 49687,
#  u'macho': 40082,
#  u'oversight': 45314,
#  u'methodical': 41833,
#  u'alequin': 15467,
#  u'downloading': 26901,
#  u'paychecks': 45977,
#  u'flatbed': 30056,
#  u'jerk': 36365,
#  u'saldano': 51595,
#  u'67576': 13682,
#  u'saldana': 51594,
#  u'choice': 21681,
#  u'elwin': 27917,
#  u'embark': 27939,
#  u'murchison': 43052,
#  u'meceo': 41501,
#  u'rationality': 49032,
#  u'knapsack': 37640,
#  u'stays': 54917,
#  u'davey': 24602,
#  u'exact': 28782,
#  u'minute': 42154,
#  u'696': 13742,
#  u'preuss': 47709,
#  u'notations': 44176,
#  u'cooks': 23337,
#  u'skelos': 53769,
#  u'09066': 8690,
#  u'cedeno': 21120,
#  u'underlain': 58431,
#  u'skewed': 53779,
#  u'pursue': 48350,
#  u'cooke': 23331,
#  u'hodgins': 33750,
#  u'reimpose': 49689,
#  u'masturbated': 40886,
#  u'ealing': 27353,
#  u'2140a': 11975,
#  u'meador': 41462,
#  u'meadow': 41463,
#  u'lapierre': 38374,
#  u'adorno': 15036,
#  u'hindered': 33647,
#  u'brucciani': 19773,
#  u'runko': 51331,
#  u'shirts': 53289,
#  u'traill': 57537,
#  u'incrementally': 34902,
#  u'excerpts': 28826,
#  u'midsentence': 41953,
#  u'medpage': 41551,
#  u'abdullah': 14470,
#  u'goldston': 31872,
#  u'boose': 19121,
#  u'seminerio': 52657,
#  u'penoyer': 46185,
#  u'695': 13741,
#  u'ground': 32349,
#  u'unintentionally': 58633,
#  u'drafted': 26931,
#  u'mcbean': 41105,
#  u'webmoney': 60340,
#  u'pochily': 46987,
#  u'storelli': 55188,
#  u'shekhman': 53169,
#  u'separate': 52714,
#  u'address': 14899,
#  u'ratio': 49027,
#  u'dwindling': 27295,
#  u'tremont': 57712,
#  u'benson': 18295,
#  u'briggs': 19604,
#  u'enroll': 28221,
#  u'fuchsberg': 30815,
#  u'accomplishes': 14693,
#  u'dusty': 27264,
#  u'impacted': 34580,
#  u'procedurally': 47855,
#  u'example': 28802,
#  u'cusack': 24227,
#  u'colonna': 22456,
#  u'accomplished': 14692,
#  u'loverde': 39785,
#  u'06809': 6558,
#  u'06808': 6557,
#  u'06807': 6556,
#  u'06806': 6555,
#  u'06805': 6554,
#  u'grimes': 32282,
#  u'06802': 6553,
#  u'vituperation': 59840,
#  u'gaudiosi': 31264,
#  u'1025i': 9731,
#  ...}

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 12

# %%
def plot_roc(actual,forecast,name):
    
    #ROC
    fpr, tpr, thresholds = metrics.roc_curve(actual, forecast)

    #AUC
    aucc = metrics.auc(fpr, tpr)

    plt.plot(fpr, tpr, label = name + ' AUC: '+str(round(aucc, 4)))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.grid(True)
    plt.legend(loc = 'lower right', title='AUC')

# %%
#Fitting logistic regression to vectorizer
logistic = LogisticRegression(random_state=33)

logistic.fit(vect_train, Y_train['Y'])
logistic_vect_fcst = logistic.predict_proba(vect_test)[:,1]

    
plot_roc(Y_test, logistic_vect_fcst,'Logistic Regression - Vectorizer')

# %%
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    print("\tAffirmed\t\t\tModified")
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_informative_features(X_vect,logistic)
# Out:
# 	Affirmed			Modified
# 	-5.7699	affirmed       		9.1508	dismissed
# 	-1.1305	unanimously    		8.3089	modified
# 	-0.9992	county         		6.1582	reversed
# 	-0.8210	ordered        		1.6099	vacating
# 	-0.8078	court          		1.0101	remitted
# 	-0.6961	appealed       		0.8971	modify
# 	-0.5852	perceive       		0.8690	reducing
# 	-0.4606	defendant      		0.8411	concede
# 	-0.4531	460            		0.7917	nobis
# 	-0.4247	decline        		0.7851	coram
# 	-0.4168	concur         		0.7375	writ
# 	-0.4000	degree         		0.6338	dismissing
# 	-0.3738	withdraw       		0.6183	matter
# 	-0.3147	reviewed       		0.6081	extent
# 	-0.3138	costs          		0.5870	reargument
# 	-0.2951	final          		0.5857	barnes
# 	-0.2923	judgment       		0.5742	affirming
# 	-0.2838	crawford       		0.5739	indicated
# 	-0.2758	extraordinary  		0.5737	withdrawn
# 	-0.2743	suitte         		0.5563	shall

# %% [markdown]
# ###  Bag of words excluding leakage

# %%
#Clean keywords
X_train_ex = X_train.Text.replace(['affirmed|dismissed|modified|reversed'],'', regex=True)
X_test_ex = X_test.Text.replace(['affirmed|dismissed|modified|reversed'],'', regex=True)

# %%
#Create vectorizers
count_vect_ex = CountVectorizer(min_df=1, stop_words='english', binary='True')

#Convert a collection of text documents to a matrix of token counts
X_vect_ex = count_vect_ex.fit(X_train_ex)

#Transform the training and test data to sparse format
vect_train_ex = X_vect_ex.transform(X_train_ex)
vect_test_ex = X_vect_ex.transform(X_test_ex)

# %%
#Fitting logistic regression to vectorizer
logistic_ex = LogisticRegression(random_state=33)

logistic_ex.fit(vect_train_ex, Y_train['Y'])
logistic_vect_fcst_ex = logistic_ex.predict_proba(vect_test_ex)[:,1]
   
plot_roc(Y_test, logistic_vect_fcst_ex,'Logistic Regression - Vectorizer')

# %%
show_most_informative_features(X_vect_ex,logistic_ex,50)
# Out:
# 	Affirmed			Modified
# 	-2.3417	appealed       		4.4768	vacating
# 	-2.3358	perceive       		3.1807	remitted
# 	-2.0123	county         		2.9780	remanded
# 	-1.8434	unanimously    		2.7010	dismissing
# 	-1.5937	ordered        		2.6606	modify
# 	-1.5313	460            		2.6342	moot
# 	-1.5116	reserved       		2.6306	superseded
# 	-1.4779	court          		2.6026	reducing
# 	-1.2446	crawford       		2.5717	concede
# 	-1.2197	suitte         		2.2593	academic
# 	-1.1515	final          		1.9347	said
# 	-1.1505	decline        		1.8963	vacated
# 	-1.1421	concur         		1.8858	reverse
# 	-1.1159	631            		1.7746	remanding
# 	-1.1047	theodore       		1.6794	insofar
# 	-1.0798	specified      		1.6495	reinstated
# 	-1.0257	discern        		1.6450	deported
# 	-1.0132	935            		1.6015	lies
# 	-0.9742	extraordinary  		1.5225	reversing
# 	-0.9608	judgments      		1.5154	granted
# 	-0.9372	dehors         		1.4640	affirming
# 	-0.9189	38             		1.3709	barnes
# 	-0.8840	opinion        		1.3443	extent
# 	-0.8788	hudson         		1.3347	reclassified
# 	-0.8659	properly       		1.2762	matter
# 	-0.8493	stipulated     		1.2625	indicated
# 	-0.8464	benefit        		1.2289	directing
# 	-0.8195	majority       		1.2103	indictment
# 	-0.8177	satisfaction   		1.1678	herewith
# 	-0.8111	sanders        		1.1589	shall
# 	-0.8056	hines          		1.1345	prosecute
# 	-0.8047	named          		1.1302	stipulation
# 	-0.7938	exceed         		1.1228	nobis
# 	-0.7938	318            		1.1078	assign
# 	-0.7918	discovery      		1.1035	salcedo
# 	-0.7845	1349           		1.0991	coram
# 	-0.7842	includes       		1.0965	hereto
# 	-0.7701	837            		1.0891	es
# 	-0.7678	saunders       		1.0881	accordance
# 	-0.7656	reviewed       		1.0791	jon
# 	-0.7587	propriety      		1.0665	receipt
# 	-0.7563	laboratory     		1.0544	padro
# 	-0.7553	providently    		1.0469	withheld
# 	-0.7531	acquittal      		1.0182	ralph
# 	-0.7526	accepting      		0.9960	suggesting
# 	-0.7442	withdraw       		0.9937	936
# 	-0.7383	521            		0.9921	accordingly
# 	-0.7376	lingle         		0.9819	reading
# 	-0.7372	stein          		0.9758	deleting
# 	-0.7346	series         		0.9708	affirmance

# %% [markdown]
# ### Bi-gram Bag of Words

# %%
#Create vectorizers
count_vect_bi = CountVectorizer(min_df=1, stop_words='english', ngram_range=(2, 2), binary='True')

#Convert a collection of text documents to a matrix of token counts
X_vect_bi = count_vect_bi.fit(X_train_ex)

#Transform the training and test data to sparse format
vect_train_bi = X_vect_bi.transform(X_train_ex)
vect_test_bi = X_vect_bi.transform(X_test_ex)

# %%
#Fitting logistic regression to vectorizer
logistic_bi = LogisticRegression(random_state=33)

logistic_bi.fit(vect_train_bi, Y_train['Y'])
logistic_vect_fcst_bi = logistic_bi.predict_proba(vect_test_bi)[:,1]
   
plot_roc(Y_test, logistic_vect_fcst_bi,'Logistic Regression - Vectorizer')

# %%
show_most_informative_features(X_vect_bi,logistic_bi,50)
# Out:
# 	Affirmed			Modified
# 	-2.1308	ordered judgment		4.2577	unanimously law
# 	-2.0536	appealed unanimously		3.2176	judgment law
# 	-1.5627	unanimously memorandum		2.2966	ordered appeal
# 	-1.4790	appellant judgment		1.7605	new trial
# 	-1.3114	judgment appealed		1.6866	order law
# 	-1.1348	unanimously present		1.6696	lv ny3d
# 	-1.0471	ordered order  		1.6057	matter remitted
# 	-1.0178	respondent judgment		1.6013	discretion justice
# 	-0.9977	unanimously opinion		1.5795	matter discretion
# 	-0.9850	unanimously verdict		1.5055	law extent
# 	-0.8696	order costs    		1.4348	ordered said
# 	-0.8504	county court   		1.4247	extent indicated
# 	-0.8207	unanimously costs		1.2782	law vacating
# 	-0.7783	460 50         		1.2724	appellant motion
# 	-0.7261	unanimously counsel		1.2722	denied present
# 	-0.7192	ordered judgments		1.2442	unanimously matter
# 	-0.7028	unanimously defendant		1.1799	said appeal
# 	-0.6779	supreme court  		1.1553	law matter
# 	-0.6568	excessive ordered		1.1541	vacating sentence
# 	-0.6489	justice cpl    		1.1540	matter remanded
# 	-0.6417	ordered sentence		1.1484	excessive extent
# 	-0.6277	york respondent		1.1453	people concede
# 	-0.6206	cpl 460        		1.1413	appeal unanimously
# 	-0.5975	appeal defendant		1.1189	appeal order
# 	-0.5873	defendant appellant		1.1139	judgment memorandum
# 	-0.5666	sentence concur		1.1107	extent vacating
# 	-0.5461	jj concur      		1.0039	justice extent
# 	-0.5417	71 ad2d        		0.9457	trial ordered
# 	-0.5398	unanimously application		0.9412	remitted county
# 	-0.5308	38 1979        		0.9328	plea vacated
# 	-0.5304	proceedings pursuant		0.9301	extent reducing
# 	-0.5299	unanimously court		0.9187	appeal judgment
# 	-0.5294	crawford 71    		0.8967	appeal moot
# 	-0.5280	ordered resentence		0.8914	law costs
# 	-0.5218	judgments supreme		0.8749	justice reducing
# 	-0.5214	decline exercise		0.8742	judgment matter
# 	-0.5199	ad2d 38        		0.8650	imposed thereon
# 	-0.5129	limited motion 		0.8491	modify judgment
# 	-0.5098	opinion order  		0.8262	law new
# 	-0.5052	excessive people		0.8175	people correctly
# 	-0.4942	people crawford		0.8151	motion reargument
# 	-0.4791	sentence opinion		0.7786	correctly concede
# 	-0.4790	ground sentence		0.7542	coram nobis
# 	-0.4769	district attorney		0.7511	light determination
# 	-0.4583	order filed    		0.7448	writ error
# 	-0.4532	1979 appeal    		0.7448	error coram
# 	-0.4525	division department		0.7163	lv 10
# 	-0.4494	judgment contrary		0.7102	dismissing count
# 	-0.4477	court properly 		0.6941	vacated matter
# 	-0.4410	exercise power 		0.6825	order court

# %% [markdown]
# ### 3-Gram

# %%
#Create vectorizers
count_vect_tri = CountVectorizer(min_df=1, stop_words='english', ngram_range=(3, 3), binary='True')

#Convert a collection of text documents to a matrix of token counts
X_vect_tri = count_vect_tri.fit(X_train_ex)

#Transform the training and test data to sparse format
vect_train_tri = X_vect_tri.transform(X_train_ex)
vect_test_tri = X_vect_tri.transform(X_test_ex)

# %%
#Fitting logistic regression to vectorizer
logistic_tri = LogisticRegression(random_state=33)

logistic_tri.fit(vect_train_tri, Y_train['Y'])
logistic_vect_fcst_tri = logistic_tri.predict_proba(vect_test_tri)[:,1]
   
plot_roc(Y_test, logistic_vect_fcst_tri,'Logistic Regression - Vectorizer')

# %%
show_most_informative_features(X_vect_tri,logistic_tri)
# Out:
# 	Affirmed			Modified
# 	-2.5007	appealed unanimously memorandum		3.4983	ordered judgment law
# 	-1.9178	ordered judgment appealed		2.6712	unanimously law extent
# 	-1.8964	appealed unanimously present		2.4940	appealed unanimously law
# 	-1.5881	judgment appealed unanimously		2.4469	matter discretion justice
# 	-1.2550	concur ordered judgment		2.2767	years unanimously law
# 	-1.1990	unanimously opinion order		1.8202	unanimously matter discretion
# 	-1.1718	ordered order costs		1.5687	ordered said appeal
# 	-1.0669	appellant judgment supreme		1.4228	ordered order law
# 	-0.9772	unanimously memorandum defendant		1.4065	law extent vacating
# 	-0.8832	appealed unanimously costs		1.2673	remitted county court
# 	-0.8217	unanimously court properly		1.2013	matter remitted county
# 	-0.7978	new york respondent		1.1861	excessive extent indicated
# 	-0.7874	years unanimously defendant		1.1542	people correctly concede
# 	-0.7872	ordered judgment defendant		1.1335	appeal judgment supreme
# 	-0.7830	opinion order filed		1.1168	new trial ordered
# 	-0.7541	unanimously counsel motion		1.1075	said appeal unanimously
# 	-0.7391	appealed unanimously people		1.1038	remitted supreme court
# 	-0.7225	counsel respondent judgment		1.0960	appellant motion reargument
# 	-0.7183	unanimously verdict based		1.0720	matter remitted supreme
# 	-0.7097	order costs disbursements		1.0577	discretion justice extent

# %% [markdown]
# #### TF-IDF

# %%
#Create vectorizers
tfidf = TfidfVectorizer(min_df=1, stop_words='english', binary='True')

#Convert a collection of text documents to a matrix of token counts
X_tfidf = tfidf.fit(X_train_ex)

#Transform the training and test data to sparse format
tfidf_train = X_tfidf.transform(X_train_ex)
tfidf_test = X_tfidf.transform(X_test_ex)

# %%
#tfidf.get_stop_words()

# %%
#Fitting logistic regression to vectorizer
logistic_tf = LogisticRegression(random_state=33)

logistic_tf.fit(tfidf_train, Y_train['Y'])
logistic_tf_fcst = logistic_tf.predict_proba(tfidf_test)[:,1]
   
plot_roc(Y_test, logistic_tf_fcst,'Logistic Regression - Vectorizer')

# %%
show_most_informative_features(X_tfidf,logistic_tf,50)
# Out:
# 	Affirmed			Modified
# 	-6.2420	appealed       		11.7781	vacating
# 	-5.0623	properly       		10.3956	matter
# 	-3.8126	unanimously    		10.3893	remitted
# 	-3.6848	perceive       		8.3883	concede
# 	-3.5033	decline        		7.6795	modify
# 	-3.4079	contention     		7.3620	vacated
# 	-3.0038	unpreserved    		6.6092	dismissing
# 	-2.9327	merit          		6.0369	reducing
# 	-2.7871	affirm         		6.0362	extent
# 	-2.7512	ordered        		6.0011	reargument
# 	-2.7083	withdraw       		5.7373	nobis
# 	-2.6358	review         		5.7181	coram
# 	-2.6148	reject         		5.6848	writ
# 	-2.6135	judgment       		5.6189	remanded
# 	-2.5889	county         		5.5055	indicated
# 	-2.5471	lv             		5.3288	said
# 	-2.5129	contrary       		5.2796	indictment
# 	-2.4421	ny2d           		5.0865	accordingly
# 	-2.4337	event          		4.8928	reverse
# 	-2.3841	460            		4.8305	error
# 	-2.3147	plea           		4.7828	moot
# 	-2.2964	court          		4.7653	academic
# 	-2.1487	suitte         		4.5821	remit
# 	-2.1266	imposing       		4.4215	decision
# 	-2.0760	38             		4.3740	granted
# 	-2.0725	degree         		3.8235	agree
# 	-2.0714	rendered       		3.7748	reversing
# 	-1.9928	abuse          		3.5684	conviction
# 	-1.9909	crawford       		3.5675	accordance
# 	-1.9634	counsel        		3.5377	determination
# 	-1.9443	extraordinary  		3.5344	justice
# 	-1.9077	basis          		3.5025	shall
# 	-1.8744	reviewed       		3.4786	remanding
# 	-1.8708	exercised      		3.4467	proceedings
# 	-1.8238	named          		3.4264	count
# 	-1.8222	record         		3.3900	insofar
# 	-1.8069	opinion        		3.3873	concurrently
# 	-1.7972	defendant      		3.2800	resentencing
# 	-1.7870	deliberation   		3.2736	erred
# 	-1.7794	claims         		3.1417	address
# 	-1.7547	satisfaction   		3.1314	directing
# 	-1.7483	guilty         		3.0934	need
# 	-1.7330	71             		3.0459	affirming
# 	-1.7265	district       		2.9901	herewith
# 	-1.6951	convicting     		2.9668	barnes
# 	-1.6854	631            		2.9445	reach
# 	-1.6730	supreme        		2.9145	dated
# 	-1.6499	downward       		2.8887	reinstated
# 	-1.5986	providently    		2.7261	463
# 	-1.5982	concur         		2.6548	vacate

# %% [markdown]
# ### Clarification on meaning of Penal Law articles that were significant
# 460 - Enterprise Corruption - organized crime
# 38 -

# %% [markdown]
# #### TFIDF Bigram

# %%
#Create vectorizers
tfidf_bi = TfidfVectorizer(min_df=1, stop_words='english', ngram_range=(2, 2), max_df = 0.5, binary='True')

#Convert a collection of text documents to a matrix of token counts
X_tfidf_bi = tfidf_bi.fit(X_train_ex)

#Transform the training and test data to sparse format
tfidf_train_bi = X_tfidf_bi.transform(X_train_ex)
tfidf_test_bi = X_tfidf_bi.transform(X_test_ex)

# %%
#Fitting logistic regression to vectorizer
logistic_tf_bi = LogisticRegression(random_state=33, C= 0.7)

logistic_tf_bi.fit(tfidf_train_bi, Y_train['Y'])
logistic_tf_fcst_bi = logistic_tf_bi.predict_proba(tfidf_test_bi)[:,1]
   
plot_roc(Y_test, logistic_tf_fcst_bi,'Logistic Regression - Vectorizer')

# %%
show_most_informative_features(X_tfidf_bi,logistic_tf_bi,20)
# Out:
# 	Affirmed			Modified
# 	-5.3243	unanimously memorandum		10.4630	unanimously law
# 	-4.5716	ordered judgment		7.7453	judgment law
# 	-3.7841	appealed unanimously		7.7258	matter remitted
# 	-3.6801	court properly 		5.3882	discretion justice
# 	-3.6088	judgment appealed		5.3610	new trial
# 	-2.8707	defendant contention		5.3318	matter discretion
# 	-2.8650	appellant judgment		5.2057	denied present
# 	-2.8137	contrary defendant		5.0861	appellant motion
# 	-2.7611	appeal defendant		4.4928	vacating sentence
# 	-2.6357	unanimously present		4.3464	coram nobis
# 	-2.6330	properly denied		4.3379	writ error
# 	-2.6062	imposing sentence		4.3379	error coram
# 	-2.5766	judgment defendant		4.3161	ordered said
# 	-2.4715	lv denied      		4.2586	law vacating
# 	-2.4634	sentence ordered		4.2077	judgment matter
# 	-2.3957	unanimously court		4.1260	law extent
# 	-2.3924	plea guilty    		4.0764	law matter
# 	-2.3165	respondent appeal		4.0425	extent indicated
# 	-2.3005	division department		4.0335	remitted county
# 	-2.2988	supreme court  		3.9691	modify judgment

# %%
def show_most_informative_features_int(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    feature_names = filter(None, list(map(lambda x: select_num(x), feature_names)))
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    print("\tAffirmed\t\t\tModified")
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        
        print("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
def select_num(val):
    print(val)
    try: 
        int(val)
        print(val)
        return val
    except ValueError:
        pass
